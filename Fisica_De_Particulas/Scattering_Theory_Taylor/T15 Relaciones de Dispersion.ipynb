# %% [markdown]
# **Objetivo:** llevamos todo el libro tratando las cosas que se pueden hacer con la amplitud de scattering, cuando el sistema tiene ciertas simetrías, etc. También hemos aprendido a calcular la amplitud de scattering de varias maneras: mediante la aprox. de Born, o a partir del desfasaje (ya sea calculado resolviendo numéricamente la ec. de Calogero o comparando el desfase de la función radial regular con el de la onda libre en onda-l y obteniendo a partir de ahí el desfasaje módulo $\pi$, para inmediatamente después calcular los autovalores del operador $S$ en la base de momento angular cuando el sistema tenía simetría de revolución y hallar así el desarrollo en ondas parciales de la amplitud de scattering que, si estábamos a energía suficientemente baja, requeriría de pocos términos). Ahora queremos encontrar otros métodos para calcular la amplitud de scattering, ya sea la total (en función de la energía y del momento transferido) o de las amplitudes parciales (funciones exclusivamente de la energía). Para ello, planteamos ciertas identidades integrales de las que podremos calcular estas amplitudes

# %% [markdown]
# **Nota:** estas integrales nos llegarán desde $E=0$ hasta $E\to\infty$, de modo que necesariamente a partir de cierto valor de energía deberíamos empezar a aplicar la teoría de scattering cuántico relativista en lugar de la no-relativista. Sin embargo, se puede demostrar que la contribución del integrando en el intervalo de energías relativistas es tan pequeña que es despreciable, de modo que podemos ceñirnos a la teoría no-relativista e integrar hasta infinito en las energías

# %% [markdown]
# # 1. Relación de dispersión para amplitudes parciales

# %% [markdown]
# - Consideremos la integral:
#
# $$\oint_C \frac{f_l(E')}{E'-E}dE'$$
