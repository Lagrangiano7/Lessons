# %%
# 2D Ising model

import numpy as np
import matplotlib.pyplot as plt


# System parameters
N = 100
J=1
k=1
T = 1
B=30
mu = 1

# Iterations

M=10000

def energy(system):
    firstTerm = 0
    for col in range(N-1):
        firstTerm += system[:,col]*system[:,col+1]
        firstTerm += system[col, :]*system[col+1, :]
    firstTerm += system[:,-1]*system[:,0] + system[-1,:]*system[0,:]
    firstTerm *= -J

    secondTerm = -B*mu*np.sum(system)

    return np.sum(firstTerm)+secondTerm

# Initial state
system = np.random.choice([-1,1], size=(N,N))

E0 = energy(system)

state = np.zeros((N,N,M))
state[:,:,0]=system

for i in range(1, M):
    system1 = system.copy()
    ind_x = np.random.randint(0,N)
    ind_y = np.random.randint(0, N)

    system1[ind_x, ind_y]*=-1

    E1 = energy(system1)
    
    if E1 < E0:
        system=system1.copy()
        E0=E1
    else:
        prob = np.exp( (E0-E1)/(k*T) )
        dice = np.random.random()
        if dice < prob:
            system=system1.copy()
            E0=E1
    state[:,:,i]=system

plt.imshow(system)
plt.show()

# %%
# Animación
from matplotlib.animation import FuncAnimation
from IPython.core.display import HTML

fig, ax = plt.subplots()

def animacion(frames):
    ax.clear()
    ax.imshow(state[:,:,frames], aspect='auto', interpolation='nearest')
    
anim=FuncAnimation(fig,animacion,frames=1000,interval=)
HTML(anim.to_jshtml())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 11
#       8     ax.clear()
#       9     ax.imshow(state[:,:,frames], aspect='auto', interpolation='nearest')
# ---> 11 anim=FuncAnimation(fig,animacion,frames=500,interval=(500,1000))
#      12 HTML(anim.to_jshtml())
#
# File /usr/lib/python3/dist-packages/matplotlib/animation.py:1660, in FuncAnimation.__init__(self, fig, func, frames, init_func, fargs, save_count, cache_frame_data, **kwargs)
#    1657 # Needs to be initialized so the draw functions work without checking
#    1658 self._save_seq = []
# -> 1660 super().__init__(fig, **kwargs)
#    1662 # Need to reset the saved seq, since right now it will contain data
#    1663 # for a single frame from init, which is not what we want.
#    1664 self._save_seq = []
#
# File /usr/lib/python3/dist-packages/matplotlib/animation.py:1394, in TimedAnimation.__init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1391 # If we're not given an event source, create a new timer. This permits
#    1392 # sharing timers between animation objects for syncing animations.
#    1393 if event_source is None:
# -> 1394     event_source = fig.canvas.new_timer(interval=self._interval)
#    1395 super().__init__(fig, event_source=event_source, *args, **kwargs)
#
# File /usr/lib/python3/dist-packages/matplotlib/backend_bases.py:2491, in FigureCanvasBase.new_timer(self, interval, callbacks)
#    2468 def new_timer(self, interval=None, callbacks=None):
#    2469     """
#    2470     Create a new backend-specific subclass of `.Timer`.
#    2471
#    (...)
#    2489     >>> timer = fig.canvas.new_timer(callbacks=[(f1, (1,), {'a': 3})])
#    2490     """
# -> 2491     return self._timer_cls(interval=interval, callbacks=callbacks)
#
# File /usr/lib/python3/dist-packages/matplotlib/backend_bases.py:1092, in TimerBase.__init__(self, interval, callbacks)
#    1090 self.callbacks = [] if callbacks is None else callbacks.copy()
#    1091 # Set .interval and not ._interval to go through the property setter.
# -> 1092 self.interval = 1000 if interval is None else interval
#    1093 self.single_shot = False
#
# File /usr/lib/python3/dist-packages/matplotlib/backend_bases.py:1132, in TimerBase.interval(self, interval)
#    1128 @interval.setter
#    1129 def interval(self, interval):
#    1130     # Force to int since none of the backends actually support fractional
#    1131     # milliseconds, and some error or give warnings.
# -> 1132     interval = int(interval)
#    1133     self._interval = interval
#    1134     self._timer_set_interval()
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'tuple'
